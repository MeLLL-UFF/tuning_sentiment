# %%
#import pandas as pd
#from google.colab import drive
#drive.mount('/gdrive')

# %%
#%cd /gdrive/My Drive/Colab Notebooks/estudo-orientado/relatorio/expr_results

# %%
dict = {
    "fileNames" : [
                   "irony",
                   "sarcasm",
                   "aisopos",
                   "SemEval-Fig",
                   "sentiment140",
                   "person",
                   "hobbit",
                   "iphone6",
                   "movie",
                   "sanders",
                   "Narr",
                   "archeage",
                   "SemEval18",
                   "OMD",
                   "HCR",
                   "STS-gold",
                   "SentiStrength",
                   "Target-dependent",
                   "Vader",
                   "SemEval13",
                   "SemEval17",
                   "SemEval16"
                  ]
}

# %%
def deParaDatasetName(textDe):
  if textDe == 'ntua':
    return 'aisopos'
  elif textDe == 'SemEval15-Task11':
    return 'SemEval-Fig'
  elif textDe == 'iphone':
    return 'iphone6'
  elif textDe == 'Narr-KDML-2012':
    return 'Narr'
  elif textDe == 'VADER':
    return 'Vader'
  elif textDe == 'SemEval17-test':
    return 'SemEval17'
  elif textDe == 'debate08':
    return 'OMD'
  else:
    return textDe

# %%
def deParaEmbeddingName(textDe):
  if textDe == 'W2V-GN':
    return 'w2v-GN'
  elif textDe == 'GloveWP':
    return 'GloVe-WP'
  elif textDe == 'FastText':
    return 'fastText'
  elif textDe == 'GloveTW':
    return 'GloVe-TWT'
  elif textDe == 'Bert: bert-base-uncased / STATIC_AVG':
    return 'Bert-static'
  elif textDe == 'TFIDF':
    return 'TF-IDF'
  elif textDe == 'W2VAraque':
    return 'w2v-Araque'
  elif textDe == 'W2VEdin':
    return 'w2v-Edin'
  elif textDe == 'Roberta: roberta-base / STATIC_AVG':
    return 'Roberta-static'
  elif textDe == 'Roberta: roberta-base / CONTEXT_CONCAT':
    return 'Roberta-context'
  elif textDe == 'Bert: bert-base-uncased / CONTEXT_CONCAT':
    return 'Bert-context'
  elif textDe == 'Roberta: RoBERTa_sentiment_tuned/ / CONTEXT_CONCAT':
    return 'Roberta-sent140'
  elif textDe == 'Bert: BERT_sentiment_tuned/ / CONTEXT_CONCAT':
    return 'Bert-sent140'
  elif textDe == 'Roberta: ./RoBERTaedinV2LM / CONTEXT_CONCAT':
    return 'Roberta-edin'
  elif textDe == 'Bert: ./BERTedinV2 / CONTEXT_CONCAT':
    return 'Bert-edin'
  elif textDe == 'Roberta: ./RoBER50kLM / CONTEXT_CONCAT':
    return 'RoBerta-edin50'
  elif textDe == 'Roberta: ./RoBER250kLM / CONTEXT_CONCAT':
    return 'RoBerta-edin250'
  elif textDe == "Roberta: ./RoBER500kLM / CONTEXT_CONCAT":
    return 'RoBerta-edin500'
  elif textDe == "Roberta: ./RoBER1500kLM / CONTEXT_CONCAT":
    return 'RoBerta-edin1500'
  elif textDe == "Roberta: ./RoBER22DTLM / CONTEXT_CONCAT":
    return 'RoBerta-Dataset'
  elif textDe == "Bert: ./BERT22DT / CONTEXT_CONCAT":
    return 'Bert-Dataset'
  elif textDe == 'Bert: ./BERT50K / CONTEXT_CONCAT':
    return 'Bert-edin50'
  elif textDe == 'Bert: ./BERT250K / CONTEXT_CONCAT':
    return 'Bert-edin250'
  elif textDe == "Bert: ./BERT500K / CONTEXT_CONCAT":
    return 'Bert-edin500'
  elif textDe == "Bert: ./BERT1500K / CONTEXT_CONCAT":
    return 'Bert-edin1500'
  elif textDe == 'Roberta: ./RoBERTaToken250LM / CONTEXT_CONCAT':
    return 'RoBerta-edin250-token'
  elif textDe == "Roberta: ./RoBERTaToken500LM / CONTEXT_CONCAT":
    return 'RoBerta-edin500-token'
  elif textDe == "Roberta: ./RoBERTaToken1500LM / CONTEXT_CONCAT":
    return 'RoBerta-edin1500-token'
  elif textDe == "Roberta: ./RoBERTaToken6600LM / CONTEXT_CONCAT":
    return 'RoBerta-edin-token'
  elif textDe == "BERTweet_base_transformers_CONTEXT":
    return 'Bertweet'
  elif textDe == "./BERTweetFinetuning_CONTEXT":
    return 'Bertweet-edin-50'
  elif textDe == "./BERTweetFinetuning250_CONTEXT":
    return 'Bertweet-edin-250'
  elif textDe == "./BERTweetFinetuning500_CONTEXT":
    return 'Bertweet-edin-500'
  elif textDe == "./BERTweetFinetuning1500_CONTEXT":
    return 'Bertweet-edin-150'
  elif textDe == "./BERTweetFinetuning22DT_CONTEXT":
    return 'Bertweet-edin-22DT'


  else:
    return textDe

# %%
def deParaClassifierName(textDe):
  if textDe == 'MLPClassifier':
    return 'MLP'
  elif textDe == 'Reg_Logistica':
    return 'LR'
  elif textDe == 'Random_Forest':
    return 'RF'
  else:
    return textDe

# %%
import glob
import pandas as pd

########## Contextualizado ##########
df_roberta = pd.read_csv(glob.glob("./RoBERTaXgboostLM/Pivot_tables/Final_Result_*.csv")[0],sep=",")
df_bert = pd.read_csv(glob.glob("./BERTXgboost/Pivot_tables/Final_Result_*.csv")[0],sep=",")
df_bertweet = pd.read_csv(glob.glob("./BERTweetXgboost/Pivot_tables/Final_Result_*.csv")[0],sep=",")


########## Estatico ##########
#dfstatic = pd.read_csv(glob.glob("base2/Pivot_tables/Final_Result_expr1_*.csv")[0], sep=",")
#dftfidf = pd.read_csv(glob.glob("base2/Pivot_tables/Final_Result_tfidf_*.csv")[0], sep=",")

######### Within task
#df_dataset_rob = pd.read_csv(glob.glob("./RoBERTXgboostFT22DTLM/Pivot_tables/Final_Result_*.csv")[0], sep=",")
#df_dataset_ber = pd.read_csv(glob.glob("./BERTXgboostFT22DT/Pivot_tables/Final_Result_*.csv")[0], sep=",")
#df_bt_dataset = pd.read_csv(glob.glob("./BERTweetXgboostFT22DT/Pivot_tables/Final_Result_*.csv")[0], sep=",")

############# FT RoBERTa ##############
#df_edin_rob_50 = pd.read_csv(glob.glob("./RoBERTXgboostFT50LM/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_edin_rob_250 = pd.read_csv(glob.glob("./RoBERTXgboostFT250LM/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_edin_rob_500 = pd.read_csv(glob.glob("./RoBERTXgboostFT500LM/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_edin_rob_1500 = pd.read_csv(glob.glob("./RoBERTXgboostFT1500LM/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_edin_rob_6600 = pd.read_csv(glob.glob("./RoBERTXgboostFT6600LM/Pivot_tables/Final_Result_*.csv")[0],sep=",")

############# FT BERT ##############
#df_edin_bert_50 = pd.read_csv(glob.glob("./BERTXgboostFT50/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_edin_bert_250 = pd.read_csv(glob.glob("./BERTXgboostFT250/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_edin_bert_500 = pd.read_csv(glob.glob("./BERTXgboostFT500/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_edin_bert_1500 = pd.read_csv(glob.glob("./BERTXgboostFT1500/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_edin_bert_6600 = pd.read_csv(glob.glob("./BERTXgboostFT6600/Pivot_tables/Final_Result_*.csv")[0],sep=",")

############# FT BERTweet ##############
#df_bt_edin_50 = pd.read_csv(glob.glob("./BERTweetXgboostFT50/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_bt_edin_250 = pd.read_csv(glob.glob("./BERTweetXgboostFT250/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_bt_edin_500 = pd.read_csv(glob.glob("./BERTweetXgboostFT500/Pivot_tables/Final_Result_*.csv")[0],sep=",")
#df_bt_edin_1500 = pd.read_csv(glob.glob("./BERTweetXgboostFT1500/Pivot_tables/Final_Result_*.csv")[0],sep=",")

# %%
frames = [df_roberta, df_bert,df_bertweet]

# %%
result = pd.concat(frames)

# %%
result[["accuracy", "f1_macro"]] = result[["accuracy", "f1_macro"]].apply(pd.to_numeric)

# %%
result["Data_Set"] = result["Data_Set"].apply(deParaDatasetName)
result["Embedding"] = result["Embedding"].apply(deParaEmbeddingName)
result["Classifier_Model"] = result["Classifier_Model"].apply(deParaClassifierName)

# %%
result.sort_values(by='Data_Set')
result[result['Data_Set']=='irony']
# Out:
#      accuracy  f1_macro Classifier_Model        Embedding Data_Set
# 5       65.95     57.55               LR  Roberta-context    irony
# 6       66.19     39.77               RF  Roberta-context    irony
# 7       46.67     31.00              SVM  Roberta-context    irony
# 8       70.71     63.36              MLP  Roberta-context    irony
# 9       61.67     48.30          XGboost  Roberta-context    irony
# 105     80.48     73.08               LR     Bert-context    irony
# 106     67.62     43.48               RF     Bert-context    irony
# 107     71.43     66.51              SVM     Bert-context    irony
# 108     80.48     70.87              MLP     Bert-context    irony
# 109     60.24     48.24          XGboost     Bert-context    irony
# 75      72.14     65.10               LR         Bertweet    irony
# 76      67.62     43.48               RF         Bertweet    irony
# 77      69.52     61.22              SVM         Bertweet    irony
# 78      73.33     64.96              MLP         Bertweet    irony
# 79      61.90     47.05          XGboost         Bertweet    irony

# %%
#result[(result['Classifier_Model'] == 'MLPClassifier') & (result['Embedding'] == 'Bert-context')]

# %%
result_acc = result.sort_values(by=['Data_Set', 'accuracy'], ascending=False)
result_f1 = result.sort_values(by=['Data_Set', 'f1_macro'], ascending=False)

# %%
result_acc = result_acc.drop_duplicates(subset='Data_Set', keep="first")
result_acc=result_acc.reset_index(drop=True)
result_f1 = result_f1.drop_duplicates(subset='Data_Set', keep="first")
result_f1=result_f1.reset_index(drop=True)

# %% [markdown]
# ```
# dict = {
#     "fileNames" : [
#                    "irony",
#                    "sarcasm",
#                    "aisopos",
#                    "SemEval-Fig",
#                    "sentiment140",
#                    "person",
#                    "hobbit",
#                    "iphone6",
#                    "movie",
#                    "sanders",
#                    "Narr",
#                    "archeage",
#                    "SemEval18",
#                    "OMD",
#                    "HCR",
#                    "STS-gold",
#                    "SentiStrength",
#                    "Target-dependent",
#                    "Vader",
#                    "SemEval13",
#                    "SemEval17",
#                    "SemEval16"
#                   ]
# }```

# %%
def montaTabelaLatex(df, metrica):
  first = True
  for ind in df.index:
    if first == False:
      print("\\rule{0pt}{3.8ex}")
    else:
      first = False
    print (str(df["Data_Set"][ind])+'&'+str(df[metrica][ind])+'&'+str(df["Classifier_Model"][ind])+'&'+str(df["Embedding"][ind])+'\\\\')

# %%
result_acc = result_acc.reindex([5,1,9,17,0,3,7,6,4,2,20,8,13,19,21,18,12,11,10,16,14,15])

# %%
result_acc
# Out:
#     accuracy  f1_macro Classifier_Model        Embedding          Data_Set
# 5      80.48     73.08               LR     Bert-context             irony
# 1      76.07     75.63              SVM     Bert-context           sarcasm
# 9      91.03     90.80               LR         Bertweet           aisopos
# 17     92.23     83.33               LR         Bertweet       SemEval-Fig
# 0      90.79     90.75               LR  Roberta-context      sentiment140
# 3      87.69     85.29               LR         Bertweet            person
# 7      87.93     86.29               LR  Roberta-context            hobbit
# 6      87.59     84.72              MLP         Bertweet           iphone6
# 4      89.47     81.11              MLP  Roberta-context             movie
# 2      91.17     91.11              MLP         Bertweet           sanders
# 20     95.60     95.43              MLP         Bertweet              Narr
# 8      90.74     90.51              MLP         Bertweet          archeage
# 13     88.97     88.87              SVM         Bertweet         SemEval18
# 19     87.36     86.40              SVM         Bertweet               OMD
# 21     81.55     74.11          XGboost         Bertweet               HCR
# 18     93.90     92.98               LR         Bertweet          STS-gold
# 12     86.76     86.53              SVM         Bertweet     SentiStrength
# 11     86.93     86.92              SVM         Bertweet  Target-dependent
# 10     90.80     89.38               LR         Bertweet             Vader
# 16     89.61     87.37               LR         Bertweet         SemEval13
# 14     92.56     92.08              SVM         Bertweet         SemEval17
# 15     91.03     89.05               LR         Bertweet         SemEval16

# %%
montaTabelaLatex(result_acc, "accuracy")
# Out:
# irony&80.48&LR&Bert-context\\
# \rule{0pt}{3.8ex}
# sarcasm&76.07&SVM&Bert-context\\
# \rule{0pt}{3.8ex}
# aisopos&91.03&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval-Fig&92.23&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# sentiment140&90.79&LR&Roberta-context\\
# \rule{0pt}{3.8ex}
# person&87.69&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# hobbit&87.93&LR&Roberta-context\\
# \rule{0pt}{3.8ex}
# iphone6&87.59&MLP&Bertweet\\
# \rule{0pt}{3.8ex}
# movie&89.47&MLP&Roberta-context\\
# \rule{0pt}{3.8ex}
# sanders&91.17&MLP&Bertweet\\
# \rule{0pt}{3.8ex}
# Narr&95.6&MLP&Bertweet\\
# \rule{0pt}{3.8ex}
# archeage&90.74&MLP&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval18&88.97&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# OMD&87.36&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# HCR&81.55&XGboost&Bertweet\\
# \rule{0pt}{3.8ex}
# STS-gold&93.9&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# SentiStrength&86.76&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# Target-dependent&86.93&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# Vader&90.8&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval13&89.61&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval17&92.56&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval16&91.03&LR&Bertweet\\

# %%
result_f1 = result_f1.reindex([5,1,9,17,0,3,7,6,4,2,20,8,13,19,21,18,12,11,10,16,14,15])

# %%
result_f1
# Out:
#     accuracy  f1_macro Classifier_Model        Embedding          Data_Set
# 5      80.48     73.08               LR     Bert-context             irony
# 1      76.07     75.63              SVM     Bert-context           sarcasm
# 9      91.03     90.86              SVM         Bertweet           aisopos
# 17     92.23     83.33               LR         Bertweet       SemEval-Fig
# 0      90.79     90.75               LR  Roberta-context      sentiment140
# 3      87.69     85.29               LR         Bertweet            person
# 7      87.93     86.29               LR  Roberta-context            hobbit
# 6      87.59     84.72              MLP         Bertweet           iphone6
# 4      88.95     82.12               LR         Bertweet             movie
# 2      91.17     91.11              MLP         Bertweet           sanders
# 20     95.60     95.43              MLP         Bertweet              Narr
# 8      90.74     90.51              MLP         Bertweet          archeage
# 13     88.97     88.87              SVM         Bertweet         SemEval18
# 19     87.36     86.40              SVM         Bertweet               OMD
# 21     80.50     76.77               LR         Bertweet               HCR
# 18     93.90     92.98               LR         Bertweet          STS-gold
# 12     86.76     86.53              SVM         Bertweet     SentiStrength
# 11     86.93     86.92              SVM         Bertweet  Target-dependent
# 10     90.80     89.38               LR         Bertweet             Vader
# 16     89.61     87.37               LR         Bertweet         SemEval13
# 14     92.56     92.08              SVM         Bertweet         SemEval17
# 15     91.03     89.05               LR         Bertweet         SemEval16

# %%
montaTabelaLatex(result_f1, "f1_macro")
# Out:
# irony&73.08&LR&Bert-context\\
# \rule{0pt}{3.8ex}
# sarcasm&75.63&SVM&Bert-context\\
# \rule{0pt}{3.8ex}
# aisopos&90.86&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval-Fig&83.33&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# sentiment140&90.75&LR&Roberta-context\\
# \rule{0pt}{3.8ex}
# person&85.29&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# hobbit&86.29&LR&Roberta-context\\
# \rule{0pt}{3.8ex}
# iphone6&84.72&MLP&Bertweet\\
# \rule{0pt}{3.8ex}
# movie&82.12&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# sanders&91.11&MLP&Bertweet\\
# \rule{0pt}{3.8ex}
# Narr&95.43&MLP&Bertweet\\
# \rule{0pt}{3.8ex}
# archeage&90.51&MLP&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval18&88.87&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# OMD&86.4&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# HCR&76.77&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# STS-gold&92.98&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# SentiStrength&86.53&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# Target-dependent&86.92&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# Vader&89.38&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval13&87.37&LR&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval17&92.08&SVM&Bertweet\\
# \rule{0pt}{3.8ex}
# SemEval16&89.05&LR&Bertweet\\
