# %%
def deParaDatasetName(textDe):
  if textDe == 'ntua':
    return 'ntu'
  elif textDe == 'SemEval15-Task11':
    return 'S15'
  elif textDe == 'iphone':
    return 'iph'
  elif textDe == 'Narr-KDML-2012':
    return 'Nar'
  elif textDe == 'VADER':
    return 'Vad'
  elif textDe == 'SemEval17-test':
    return 'S17'
  elif textDe == 'debate08':
    return 'OMD'
  elif textDe == 'irony':
    return 'iro'
  elif textDe == 'sarcasm':
    return 'sar'
  elif textDe == 'sentiment140':
    return 'stm'
  elif textDe == 'person':
    return 'per'
  elif textDe == 'hobbit':
    return 'hob'
  elif textDe == 'movie':
    return 'mov'
  elif textDe == 'sanders':
    return 'san'
  elif textDe == 'archeage':
    return 'arc'
  elif textDe == 'SemEval18':
    return 'S18'
  elif textDe == 'STS-gold':
    return 'STS'
  elif textDe == 'SentiStrength':
    return 'SSt'
  elif textDe == 'Target-dependent':
    return 'Tar'
  elif textDe == 'SemEval13':
    return 'S13'
  elif textDe == 'SemEval16':
    return 'S16'
  else:
    return textDe

# %%
import pandas as pd
import glob

# %%
def get_result_resume(df,models):
    df_t = df.copy()
    df_t.index=df_t['Embedding']
    del df_t['Embedding']
    df_t = df_t.T
    df_rank = pd.DataFrame()
    for dts in df['Embedding']:
        df_rank = pd.concat([df_rank,pd.DataFrame(df_t[dts].rank(ascending=False)).T],axis=0)

    dict_emb_sum = pd.DataFrame(df_rank.sum(),columns=['ranksum'])
    dict_emb_sum = dict_emb_sum.reindex(models)

    dict_emb_ranksum = dict_emb_sum.rank(ascending=True)
    dict_emb_ranksum.columns=['position']
    dict_emb_ranksum = dict_emb_ranksum.reindex(models)

    sum_wins=[]
    for col in df_rank.columns:
        sum_wins.append(len(df_rank[df_rank[col]<=1.5][col]))

    sum_wins = pd.DataFrame(sum_wins,index=df_rank.columns,columns=['wins'])
    sum_wins = sum_wins.reindex(models)

    final_result = pd.concat([sum_wins,dict_emb_sum,dict_emb_ranksum],axis=1)
    return final_result

# %%
def isTheWinner(df,model,dataset):
    df_t = df.copy()
    df_t.index=df_t['Embedding']
    del df_t['Embedding']
    df_t = df_t.T
    if df_t[dataset].rank(ascending=False)[model]==1:
        return True
    else:
        return False

# %%
def printWinnerTableFormat(df,embVal,emb, dsname):
  if isTheWinner(df,emb, dsname)==True:
    return '\\textbf{'+str(embVal)+'}'
  return embVal

# %%
def mont_dataset(tag):
    df_edin_05 = pd.read_csv(glob.glob("./Edin/BERTweet-05-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_1 = pd.read_csv(glob.glob("./Edin/BERTweet-1-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_5 = pd.read_csv(glob.glob("./Edin/BERTweet-5-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_10 = pd.read_csv(glob.glob("./Edin/BERTweet-10-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_25 = pd.read_csv(glob.glob("./Edin/BERTweet-25-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_50 = pd.read_csv(glob.glob("./Edin/BERTweet-50-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_250 = pd.read_csv(glob.glob("./Edin/BERTweet-250-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_500 = pd.read_csv(glob.glob("./Edin/BERTweet-500-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_1500 = pd.read_csv(glob.glob("./Edin/BERTweet-1500-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_6600 = pd.read_csv(glob.glob("./Edin/BERTweet-6600-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    
    df_edin_bert_05 = pd.read_csv(glob.glob("./Edin/BERT-05-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_bert_1 = pd.read_csv(glob.glob("./Edin/BERT-1-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_bert_5 = pd.read_csv(glob.glob("./Edin/BERT-5-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_bert_10 = pd.read_csv(glob.glob("./Edin/BERT-10-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_bert_25 = pd.read_csv(glob.glob("./Edin/BERT-25-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_bert_50 = pd.read_csv(glob.glob("./Edin/BERT-50-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_bert_250 = pd.read_csv(glob.glob("./Edin/BERT-250-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_bert_500 = pd.read_csv(glob.glob("./Edin/BERT-500-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_bert_1500 = pd.read_csv(glob.glob("./Edin/BERT-1500-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_bert_6600 = pd.read_csv(glob.glob("./Edin/BERT-6600-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")

    df_edin_rob_05 = pd.read_csv(glob.glob("./Edin/RoBERTa-05-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_rob_1 = pd.read_csv(glob.glob("./Edin/RoBERTa-1-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_rob_5 = pd.read_csv(glob.glob("./Edin/RoBERTa-5-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_rob_10 = pd.read_csv(glob.glob("./Edin/RoBERTa-10-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_rob_25 = pd.read_csv(glob.glob("./Edin/RoBERTa-25-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_rob_50 = pd.read_csv(glob.glob("./Edin/RoBERTa-50-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_rob_250 = pd.read_csv(glob.glob("./Edin/RoBERTa-250-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_rob_500 = pd.read_csv(glob.glob("./Edin/RoBERTa-500-LM/pivot_"+str(tag)+"*.csv")[0],sep=",")
    df_edin_rob_1500 = pd.read_csv(glob.glob("./Edin/RoBERTa-1500-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")
    df_edin_rob_6600 = pd.read_csv(glob.glob("./Edin/RoBERTa-6600-LM/pivot_"+str(tag)+"*.csv")[0], sep=",")

    df_edin = pd.DataFrame()
    df_edin = df_edin_05.assign(Bertweet_1k = df_edin_1.iloc[:,1])
    df_edin = df_edin.assign(Bertweet_5k = df_edin_5.iloc[:,1])
    df_edin = df_edin.assign(Bertweet_10k = df_edin_10.iloc[:,1])
    df_edin = df_edin.assign(Bertweet_25k = df_edin_25.iloc[:,1])
    df_edin = df_edin.assign(Bertweet_50k = df_edin_50.iloc[:,1])
    df_edin = df_edin.assign(Bertweet_250k = df_edin_250.iloc[:,1])
    df_edin = df_edin.assign(Bertweet_500k = df_edin_500.iloc[:,1])
    df_edin = df_edin.assign(Bertweet_1500k = df_edin_1500.iloc[:,1])
    df_edin = df_edin.assign(Bertweet_6600k = df_edin_6600.iloc[:,1])

    df_edin_ro = pd.DataFrame()
    df_edin_ro = df_edin_rob_05.assign(Roberta_1k = df_edin_rob_1.iloc[:,1])
    df_edin_ro = df_edin_ro.assign(Roberta_5k = df_edin_rob_5.iloc[:,1])
    df_edin_ro = df_edin_ro.assign(Roberta_10k = df_edin_rob_10.iloc[:,1])
    df_edin_ro = df_edin_ro.assign(Roberta_25k = df_edin_rob_25.iloc[:,1])
    df_edin_ro = df_edin_ro.assign(Roberta_50k = df_edin_rob_50.iloc[:,1])
    df_edin_ro = df_edin_ro.assign(Roberta_250k = df_edin_rob_250.iloc[:,1])
    df_edin_ro = df_edin_ro.assign(Roberta_500k = df_edin_rob_500.iloc[:,1])
    df_edin_ro = df_edin_ro.assign(Roberta_1500k = df_edin_rob_1500.iloc[:,1])
    df_edin_ro = df_edin_ro.assign(Roberta_6600k = df_edin_rob_6600.iloc[:,1])

    df_edin_ber = pd.DataFrame()
    df_edin_ber = df_edin_bert_05.assign(Bert_1k = df_edin_bert_1.iloc[:,1])
    df_edin_ber = df_edin_ber.assign(Bert_5k = df_edin_bert_5.iloc[:,1])
    df_edin_ber = df_edin_ber.assign(Bert_10k = df_edin_bert_10.iloc[:,1])
    df_edin_ber = df_edin_ber.assign(Bert_25k = df_edin_bert_25.iloc[:,1])
    df_edin_ber = df_edin_ber.assign(Bert_50k = df_edin_bert_50.iloc[:,1])
    df_edin_ber = df_edin_ber.assign(Bert_250k = df_edin_bert_250.iloc[:,1])
    df_edin_ber = df_edin_ber.assign(Bert_500k = df_edin_bert_500.iloc[:,1])
    df_edin_ber = df_edin_ber.assign(Bert_1500k = df_edin_bert_1500.iloc[:,1])
    df_edin_ber = df_edin_ber.assign(Bert_6600k = df_edin_bert_6600.iloc[:,1])
    
    df_edin.columns = ["Embedding", 'Bertweet_05k','Bertweet_1k','Bertweet_5k','Bertweet_10k','Bertweet_25k', 'Bertweet_50k','Bertweet_250k','Bertweet_500k','Bertweet_1500k','Bertweet_6600k']
    df_edin_ro.columns = ["Embedding", 'Roberta_05k','Roberta_1k','Roberta_5k','Roberta_10k','Roberta_25k', 'Roberta_50k','Roberta_250k','Roberta_500k','Roberta_1500k','Roberta_6600k']
    df_edin_ber.columns = ["Embedding", 'Bert_05k','Bert_1k','Bert_5k','Bert_10k','Bert_25k', 'Bert_50k','Bert_250k','Bert_500k','Bert_1500k','Bert_6600k']
    
    df_edin["Embedding"] = df_edin["Embedding"].apply(deParaDatasetName)
    df_edin_ro["Embedding"] = df_edin_ro["Embedding"].apply(deParaDatasetName)
    df_edin_ber["Embedding"] = df_edin_ber["Embedding"].apply(deParaDatasetName)
    
    df_edin = df_edin.reindex([15,20,17,4,21,18,13,14,16,19,1,11,7,12,0,2,8,9,10,3,6,5])
    df_edin_ro = df_edin_ro.reindex([15,20,17,4,21,18,13,14,16,19,1,11,7,12,0,2,8,9,10,3,6,5])
    df_edin_ber = df_edin_ber.reindex([15,20,17,4,21,18,13,14,16,19,1,11,7,12,0,2,8,9,10,3,6,5])
    
    df_edin.iloc[:,1:] = df_edin.iloc[:,1:].apply(pd.to_numeric).round(2)
    df_edin_ro.iloc[:,1:] = df_edin_ro.iloc[:,1:].apply(pd.to_numeric).round(2)
    df_edin_ber.iloc[:,1:] = df_edin_ber.iloc[:,1:].apply(pd.to_numeric).round(2)
    return df_edin_ber,df_edin_ro,df_edin

# %% [markdown]
# Reg_Logistica_accuracy, Reg_Logistica_f1_macro,
# SVM_accuracy,
# SVM_f1_macro,
# MLPClassifier_accuracy,
# MLPClassifier_f1_macro,
# Random_Forest_accuracy
# Random_Forest_f1_macro
# XGboost_accuracy
# XGboost_f1_macro

# %%
df_edin_ber,df_edin_ro,df_edin = mont_dataset('SVM_accuracy')

# %%
final_result_b = get_result_resume(df_edin_ber,['Bert_05k','Bert_1k','Bert_5k','Bert_10k','Bert_25k', 'Bert_50k','Bert_250k','Bert_500k','Bert_1500k','Bert_6600k'])
final_result_rb = get_result_resume(df_edin_ro,['Roberta_05k','Roberta_1k','Roberta_5k','Roberta_10k','Roberta_25k', 'Roberta_50k','Roberta_250k','Roberta_500k','Roberta_1500k','Roberta_6600k'])
final_result_bt = get_result_resume(df_edin,['Bertweet_05k','Bertweet_1k','Bertweet_5k','Bertweet_10k','Bertweet_25k', 'Bertweet_50k','Bertweet_250k','Bertweet_500k','Bertweet_1500k','Bertweet_6600k'])

# %%
for ind in df_edin_ber.index:
  print(df_edin_ber["Embedding"][ind]+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_05k"][ind], "Bert_05k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_1k"][ind], "Bert_1k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_5k"][ind], "Bert_5k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_10k"][ind], "Bert_10k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_25k"][ind], "Bert_25k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_50k"][ind], "Bert_50k",df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_250k"][ind], "Bert_250k",df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_500k"][ind], "Bert_500k",df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_1500k"][ind], "Bert_1500k",df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_6600k"][ind],"Bert_6600k", df_edin_ber["Embedding"][ind]))+'\\\\')
print("\\noalign{\\smallskip}\\hline")
print("\\#wins &"+str(final_result_b['wins']["Bert_05k"])+"& "+ 
      str(final_result_b['wins']["Bert_1k"])+"& "+ 
      str(final_result_b['wins']["Bert_5k"])+"& "+ 
      str(final_result_b['wins']["Bert_10k"])+"& "+ 
      str(final_result_b['wins']["Bert_25k"])+"& "+ 
      str(final_result_b['wins']["Bert_50k"])+"& "+ 
      str(final_result_b['wins']["Bert_250k"])+"& "+
      str(final_result_b['wins']["Bert_500k"])+"& "+
      str(final_result_b['wins']["Bert_1500k"])+"& "+
      str(final_result_b['wins']["Bert_6600k"])+"& "+"\\\\")
print("rank sums &"+ str(final_result_b['ranksum']["Bert_05k"])+"&"+
      str(final_result_b['ranksum']["Bert_1k"])+"&"+
      str(final_result_b['ranksum']["Bert_5k"])+"&"+
      str(final_result_b['ranksum']["Bert_10k"])+"&"+
      str(final_result_b['ranksum']["Bert_25k"])+"&"+
      str(final_result_b['ranksum']["Bert_50k"])+"&"+
      str(final_result_b['ranksum']["Bert_250k"])+"&"+
      str(final_result_b['ranksum']["Bert_500k"])+"&"+
      str(final_result_b['ranksum']["Bert_1500k"])+"&"+
      str(final_result_b['ranksum']["Bert_6600k"])+"&"+"\\\\")
print("position &"+str(final_result_b['position']['Bert_05k'])+"&"+ 
      str(final_result_b['position']['Bert_1k'])+"&"+ 
      str(final_result_b['position']['Bert_5k'])+"&"+ 
      str(final_result_b['position']['Bert_10k'])+"&"+ 
      str(final_result_b['position']['Bert_25k'])+"&"+ 
      str(final_result_b['position']['Bert_50k'])+"&"+ 
      str(final_result_b['position']['Bert_250k']) +"&"+ 
      str(final_result_b['position']['Bert_500k']) +"&"+
      str(final_result_b['position']['Bert_1500k']) +"&"+
      str(final_result_b['position']['Bert_6600k']) +"&"+"\\\\")
# Out:
# iro&73.81&74.05&72.38&66.19&76.43&73.57&\textbf{76.67}&61.19&62.07&56.74\\
# sar&68.93&70.18&74.46&67.32&73.04&\textbf{77.32}&74.46&70.36&71.31&63.69\\
# ntu&88.84&86.65&84.18&85.97&83.08&85.62&84.89&92.09&93.88&\textbf{94.38}\\
# S15&90.35&89.4&90.02&\textbf{90.64}&88.78&90.03&87.22&87.23&85.96&87.13\\
# stm&89.14&89.14&88.29&\textbf{89.41}&89.13&88.86&89.13&88.3&88.57&87.01\\
# per&84.72&82.91&\textbf{85.42}&83.14&82.91&82.01&81.1&81.32&79.5&76.16\\
# hob&83.9&85.24&86.39&\textbf{86.78}&86.18&84.85&84.29&83.72&84.15&80.89\\
# iph&81.02&81.39&81.58&82.15&81.02&81.2&82.15&81.21&80.34&78.96\\
# mov&82.72&83.43&84.49&85.2&84.5&85.03&\textbf{85.91}&83.26&82.41&82.71\\
# san&86.19&86.19&85.87&87.01&86.27&87.42&\textbf{87.66}&87.0&86.98&87.6\\
# Nar&91.93&91.44&92.42&91.52&91.6&91.28&92.5&92.83&\textbf{93.67}&93.5\\
# arc&86.85&88.07&88.94&88.19&87.49&88.01&87.95&\textbf{89.58}&88.13&88.5\\
# S18&\textbf{87.25}&86.82&86.45&86.45&86.5&86.61&86.5&86.82&87.09&86.0\\
# ...

# %%
for ind in df_edin_ber.index:
  print(df_edin_ber["Embedding"][ind]+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_05k"][ind],"Roberta_05k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_1k"][ind],"Roberta_1k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_5k"][ind],"Roberta_5k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_10k"][ind],"Roberta_10k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_25k"][ind],"Roberta_25k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_50k"][ind],"Roberta_50k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_250k"][ind],"Roberta_250k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_500k"][ind],"Roberta_500k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_1500k"][ind],"Roberta_1500k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_6600k"][ind],"Roberta_6600k", df_edin_ro["Embedding"][ind]))+'\\\\')
print("\\noalign{\\smallskip}\\hline")
print("\\#wins &"+str(final_result_rb['wins']["Roberta_05k"])+"& "+
      str(final_result_rb['wins']["Roberta_1k"])+"& "+
      str(final_result_rb['wins']["Roberta_5k"])+"& "+
      str(final_result_rb['wins']["Roberta_10k"])+"& "+
      str(final_result_rb['wins']["Roberta_25k"])+"& "+
      str(final_result_rb['wins']["Roberta_50k"])+"& "+
      str(final_result_rb['wins']["Roberta_250k"])+"& "+
      str(final_result_rb['wins']["Roberta_500k"])+"& "+
      str(final_result_rb['wins']["Roberta_1500k"])+"& "+
      str(final_result_rb['wins']["Roberta_6600k"])+"& "+"\\\\")
print("rank sums &"+ str(final_result_rb['ranksum']["Roberta_05k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_1k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_5k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_10k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_25k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_50k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_250k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_500k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_1500k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_6600k"])+"&"+"\\\\")
print("position &"+str(final_result_rb['position']['Roberta_05k']) +"&"+
      str(final_result_rb['position']['Roberta_1k']) +"&"+
      str(final_result_rb['position']['Roberta_5k']) +"&"+
      str(final_result_rb['position']['Roberta_10k']) +"&"+
      str(final_result_rb['position']['Roberta_25k']) +"&"+
      str(final_result_rb['position']['Roberta_50k']) +"&"+
      str(final_result_rb['position']['Roberta_250k']) +"&"+
      str(final_result_rb['position']['Roberta_500k']) +"&"+
      str(final_result_rb['position']['Roberta_1500k']) +"&"+
      str(final_result_rb['position']['Roberta_6600k']) +"&"+"\\\\")
# Out:
# iro&46.67&46.67&46.67&\textbf{48.1}&46.67&46.67&46.67&46.67&45.24&46.74\\
# sar&60.71&59.29&65.0&57.86&62.14&60.71&65.0&62.14&63.57&64.7\\
# ntu&81.69&81.31&79.15&81.34&82.06&85.63&87.08&90.67&\textbf{91.75}&90.41\\
# S15&83.18&83.5&84.75&86.93&84.75&85.38&86.93&\textbf{88.79}&87.24&87.03\\
# stm&85.23&86.35&89.7&85.24&87.75&88.04&88.03&87.48&\textbf{90.81}&86.35\\
# per&69.92&69.68&70.38&68.33&71.74&71.28&72.66&74.26&76.32&\textbf{77.0}\\
# hob&73.76&71.44&73.56&74.32&72.41&77.4&77.38&77.2&\textbf{77.97}&77.82\\
# iph&78.41&78.41&77.46&78.96&78.78&79.71&79.89&\textbf{80.09}&79.15&79.02\\
# mov&71.14&76.84&\textbf{81.64}&80.76&78.44&78.09&79.52&80.4&81.12&81.05\\
# san&84.39&84.23&85.21&85.78&85.13&86.27&85.86&87.17&\textbf{88.23}&86.16\\
# Nar&91.04&92.18&92.58&92.25&91.2&92.58&92.74&92.83&93.07&\textbf{93.88}\\
# arc&88.88&88.53&89.0&87.72&88.48&89.23&88.59&\textbf{89.64}&89.47&88.57\\
# S18&\textbf{87.9}&87.15&87.15&87.09&86.61&87.52&87.14&87.47&86.61&86.62\\
# ...

# %%
for ind in df_edin_ber.index:
  print(df_edin_ber["Embedding"][ind]+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_05k"][ind],"Bertweet_05k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_1k"][ind],"Bertweet_1k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_5k"][ind],"Bertweet_5k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_10k"][ind],"Bertweet_10k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_25k"][ind],"Bertweet_25k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_50k"][ind],"Bertweet_50k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_250k"][ind],"Bertweet_250k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_500k"][ind],"Bertweet_500k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_1500k"][ind],"Bertweet_1500k", df_edin["Embedding"][ind]))+        
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_6600k"][ind],"Bertweet_6600k", df_edin["Embedding"][ind]))+'\\\\')
print("\\noalign{\\smallskip}\\hline")
print("\\#wins &"+str(final_result_bt['wins']["Bertweet_05k"])+"& "+
      str(final_result_bt['wins']["Bertweet_1k"])+"& "+
      str(final_result_bt['wins']["Bertweet_5k"])+"& "+
      str(final_result_bt['wins']["Bertweet_10k"])+"& "+
      str(final_result_bt['wins']["Bertweet_25k"])+"& "+
      str(final_result_bt['wins']["Bertweet_50k"])+"& "+
      str(final_result_bt['wins']["Bertweet_250k"])+"& "+
      str(final_result_bt['wins']["Bertweet_500k"])+"& "+
      str(final_result_bt['wins']["Bertweet_1500k"])+"& "+
      str(final_result_bt['wins']["Bertweet_6600k"])+"& "+"\\\\")
print("rank sums &"+ str(final_result_bt['ranksum']["Bertweet_05k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_1k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_5k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_10k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_25k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_50k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_250k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_500k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_1500k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_6600k"])+"&"+"\\\\")
print("position &"+str(final_result_bt['position']['Bertweet_05k']) +"&"+
      str(final_result_bt['position']['Bertweet_1k']) +"&"+
      str(final_result_bt['position']['Bertweet_5k']) +"&"+
      str(final_result_bt['position']['Bertweet_10k']) +"&"+
      str(final_result_bt['position']['Bertweet_25k']) +"&"+
      str(final_result_bt['position']['Bertweet_50k']) +"&"+
      str(final_result_bt['position']['Bertweet_250k']) +"&"+
      str(final_result_bt['position']['Bertweet_500k']) +"&"+
      str(final_result_bt['position']['Bertweet_1500k']) +"&"+
      str(final_result_bt['position']['Bertweet_6600k']) +"&"+"\\\\")
# Out:
# iro&68.81&68.1&71.19&73.81&74.76&\textbf{79.76}&71.67&70.48&67.78&66.43\\
# sar&64.82&69.11&67.68&73.21&73.21&68.93&70.36&70.36&72.26&71.79\\
# ntu&89.95&91.4&91.03&92.82&93.17&92.09&93.16&93.16&\textbf{94.38}&92.45\\
# S15&90.34&92.22&90.04&\textbf{92.53}&92.23&91.6&90.03&90.04&89.4&89.09\\
# stm&90.52&91.92&\textbf{93.04}&91.36&91.07&91.9&92.19&93.02&91.45&90.52\\
# per&84.28&84.04&85.64&86.77&\textbf{86.79}&85.41&86.1&85.87&83.14&81.32\\
# hob&85.06&85.25&86.78&86.78&86.78&\textbf{87.92}&86.6&86.77&87.03&86.21\\
# iph&84.04&83.84&83.47&85.35&84.78&84.22&83.47&\textbf{85.55}&82.22&82.34\\
# mov&85.93&87.71&88.6&88.95&88.42&\textbf{89.49}&88.78&88.42&87.3&87.89\\
# san&90.03&90.69&91.42&90.93&91.18&\textbf{91.67}&91.01&91.01&89.46&90.03\\
# Nar&95.93&96.33&96.58&96.41&96.58&96.41&96.58&95.92&95.71&94.87\\
# arc&90.05&90.39&90.63&90.34&91.09&90.45&\textbf{91.21}&90.98&91.12&90.74\\
# S18&89.99&89.78&90.26&\textbf{90.48}&89.89&89.83&89.94&89.03&88.26&87.9\\
# ...

# %%
for ind in df_edin_ber.index:
  print(df_edin_ber["Embedding"][ind]+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_05k"][ind], "Bert_05k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_1k"][ind], "Bert_1k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_5k"][ind], "Bert_5k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_10k"][ind], "Bert_10k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_25k"][ind], "Bert_25k",df_edin_ber["Embedding"][ind]))+
        "&"+ str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_50k"][ind], "Bert_50k",df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_250k"][ind], "Bert_250k",df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_500k"][ind], "Bert_500k",df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_1500k"][ind], "Bert_1500k",df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ber,df_edin_ber["Bert_6600k"][ind],"Bert_6600k", df_edin_ber["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_05k"][ind],"Roberta_05k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_1k"][ind],"Roberta_1k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_5k"][ind],"Roberta_5k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_10k"][ind],"Roberta_10k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_25k"][ind],"Roberta_25k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_50k"][ind],"Roberta_50k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_250k"][ind],"Roberta_250k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_500k"][ind],"Roberta_500k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_1500k"][ind],"Roberta_1500k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin_ro,df_edin_ro["Roberta_6600k"][ind],"Roberta_6600k", df_edin_ro["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_05k"][ind],"Bertweet_05k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_1k"][ind],"Bertweet_1k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_5k"][ind],"Bertweet_5k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_10k"][ind],"Bertweet_10k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_25k"][ind],"Bertweet_25k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_50k"][ind],"Bertweet_50k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_250k"][ind],"Bertweet_250k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_500k"][ind],"Bertweet_500k", df_edin["Embedding"][ind]))+
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_1500k"][ind],"Bertweet_1500k", df_edin["Embedding"][ind]))+        
        '&'+str(printWinnerTableFormat(df_edin,df_edin["Bertweet_6600k"][ind],"Bertweet_6600k", df_edin["Embedding"][ind]))+'\\\\')
print("\\noalign{\\smallskip}\\hline")
print("\\#wins &"+str(final_result_b['wins']["Bert_05k"])+"& "+ 
      str(final_result_b['wins']["Bert_1k"])+"& "+ 
      str(final_result_b['wins']["Bert_5k"])+"& "+ 
      str(final_result_b['wins']["Bert_10k"])+"& "+ 
      str(final_result_b['wins']["Bert_25k"])+"& "+ 
      str(final_result_b['wins']["Bert_50k"])+"& "+ 
      str(final_result_b['wins']["Bert_250k"])+"& "+
      str(final_result_b['wins']["Bert_500k"])+"& "+
      str(final_result_b['wins']["Bert_1500k"])+"& "+
      str(final_result_b['wins']["Bert_6600k"])+"& "+
      str(final_result_rb['wins']["Roberta_05k"])+"& "+
      str(final_result_rb['wins']["Roberta_1k"])+"& "+
      str(final_result_rb['wins']["Roberta_5k"])+"& "+
      str(final_result_rb['wins']["Roberta_10k"])+"& "+
      str(final_result_rb['wins']["Roberta_25k"])+"& "+
      str(final_result_rb['wins']["Roberta_50k"])+"& "+
      str(final_result_rb['wins']["Roberta_250k"])+"& "+
      str(final_result_rb['wins']["Roberta_500k"])+"& "+
      str(final_result_rb['wins']["Roberta_1500k"])+"& "+
      str(final_result_rb['wins']["Roberta_6600k"])+"& "+
      str(final_result_bt['wins']["Bertweet_05k"])+"& "+
      str(final_result_bt['wins']["Bertweet_1k"])+"& "+
      str(final_result_bt['wins']["Bertweet_5k"])+"& "+
      str(final_result_bt['wins']["Bertweet_10k"])+"& "+
      str(final_result_bt['wins']["Bertweet_25k"])+"& "+
      str(final_result_bt['wins']["Bertweet_50k"])+"& "+
      str(final_result_bt['wins']["Bertweet_250k"])+"& "+
      str(final_result_bt['wins']["Bertweet_500k"])+"& "+
      str(final_result_bt['wins']["Bertweet_1500k"])+"& "+
      str(final_result_bt['wins']["Bertweet_6600k"])+"& "+"\\\\")
print("rank sums &"+ str(final_result_b['ranksum']["Bert_05k"])+"&"+
      str(final_result_b['ranksum']["Bert_1k"])+"&"+
      str(final_result_b['ranksum']["Bert_5k"])+"&"+
      str(final_result_b['ranksum']["Bert_10k"])+"&"+
      str(final_result_b['ranksum']["Bert_25k"])+"&"+
      str(final_result_b['ranksum']["Bert_50k"])+"&"+
      str(final_result_b['ranksum']["Bert_250k"])+"&"+
      str(final_result_b['ranksum']["Bert_500k"])+"&"+
      str(final_result_b['ranksum']["Bert_1500k"])+"&"+
      str(final_result_b['ranksum']["Bert_6600k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_05k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_1k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_5k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_10k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_25k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_50k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_250k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_500k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_1500k"])+"&"+
      str(final_result_rb['ranksum']["Roberta_6600k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_05k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_1k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_5k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_10k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_25k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_50k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_250k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_500k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_1500k"])+"&"+
      str(final_result_bt['ranksum']["Bertweet_6600k"])+"&"+"\\\\")
print("position &"+str(final_result_b['position']['Bert_05k'])+"&"+ 
      str(final_result_b['position']['Bert_1k'])+"&"+ 
      str(final_result_b['position']['Bert_5k'])+"&"+ 
      str(final_result_b['position']['Bert_10k'])+"&"+ 
      str(final_result_b['position']['Bert_25k'])+"&"+ 
      str(final_result_b['position']['Bert_50k'])+"&"+ 
      str(final_result_b['position']['Bert_250k']) +"&"+ 
      str(final_result_b['position']['Bert_500k']) +"&"+
      str(final_result_b['position']['Bert_1500k']) +"&"+
      str(final_result_b['position']['Bert_6600k']) +"&"+
      str(final_result_rb['position']['Roberta_05k']) +"&"+
      str(final_result_rb['position']['Roberta_1k']) +"&"+
      str(final_result_rb['position']['Roberta_5k']) +"&"+
      str(final_result_rb['position']['Roberta_10k']) +"&"+
      str(final_result_rb['position']['Roberta_25k']) +"&"+
      str(final_result_rb['position']['Roberta_50k']) +"&"+
      str(final_result_rb['position']['Roberta_250k']) +"&"+
      str(final_result_rb['position']['Roberta_500k']) +"&"+
      str(final_result_rb['position']['Roberta_1500k']) +"&"+
      str(final_result_rb['position']['Roberta_6600k']) +"&"+
      str(final_result_bt['position']['Bertweet_05k']) +"&"+
      str(final_result_bt['position']['Bertweet_1k']) +"&"+
      str(final_result_bt['position']['Bertweet_5k']) +"&"+
      str(final_result_bt['position']['Bertweet_10k']) +"&"+
      str(final_result_bt['position']['Bertweet_25k']) +"&"+
      str(final_result_bt['position']['Bertweet_50k']) +"&"+
      str(final_result_bt['position']['Bertweet_250k']) +"&"+
      str(final_result_bt['position']['Bertweet_500k']) +"&"+
      str(final_result_bt['position']['Bertweet_1500k']) +"&"+
      str(final_result_bt['position']['Bertweet_6600k']) +"&"+"\\\\")
# Out:
# iro&73.81&74.05&72.38&66.19&76.43&73.57&\textbf{76.67}&61.19&62.07&56.74&46.67&46.67&46.67&\textbf{48.1}&46.67&46.67&46.67&46.67&45.24&46.74&68.81&68.1&71.19&73.81&74.76&\textbf{79.76}&71.67&70.48&67.78&66.43\\
# sar&68.93&70.18&74.46&67.32&73.04&\textbf{77.32}&74.46&70.36&71.31&63.69&60.71&59.29&65.0&57.86&62.14&60.71&65.0&62.14&63.57&64.7&64.82&69.11&67.68&73.21&73.21&68.93&70.36&70.36&72.26&71.79\\
# ntu&88.84&86.65&84.18&85.97&83.08&85.62&84.89&92.09&93.88&\textbf{94.38}&81.69&81.31&79.15&81.34&82.06&85.63&87.08&90.67&\textbf{91.75}&90.41&89.95&91.4&91.03&92.82&93.17&92.09&93.16&93.16&\textbf{94.38}&92.45\\
# S15&90.35&89.4&90.02&\textbf{90.64}&88.78&90.03&87.22&87.23&85.96&87.13&83.18&83.5&84.75&86.93&84.75&85.38&86.93&\textbf{88.79}&87.24&87.03&90.34&92.22&90.04&\textbf{92.53}&92.23&91.6&90.03&90.04&89.4&89.09\\
# ...

# %%
indexes_=[['Bert_05k','Bert_1k','Bert_5k','Bert_10k','Bert_25k', 'Bert_50k','Bert_250k','Bert_500k','Bert_1500k','Bert_6600k'],
         ['Roberta_05k','Roberta_1k','Roberta_5k','Roberta_10k','Roberta_25k', 'Roberta_50k','Roberta_250k','Roberta_500k','Roberta_1500k','Roberta_6600k'],
         ['Bertweet_05k','Bertweet_1k','Bertweet_5k','Bertweet_10k','Bertweet_25k', 'Bertweet_50k','Bertweet_250k','Bertweet_500k','Bertweet_1500k','Bertweet_6600k']]
         
finals = [final_result_b,final_result_rb,final_result_bt]
for i in range(3):
    indexes = indexes_[i]
    count_model=0
    print_dataset=pd.DataFrame()
    sum_win=pd.Series(0,index=indexes)
    sum_rank=pd.Series(0,index=indexes)
    sum_pos=pd.Series(0,index=indexes)
    for clasf in ['Reg_Logistica_accuracy','SVM_accuracy','MLPClassifier_accuracy',
                  'Random_Forest_accuracy','XGboost_accuracy']:
        df_edin_ber,df_edin_ro,df_edin = mont_dataset(clasf)
        final_result_b = get_result_resume(df_edin_ber,['Bert_05k','Bert_1k','Bert_5k','Bert_10k','Bert_25k', 'Bert_50k','Bert_250k','Bert_500k','Bert_1500k','Bert_6600k'])
        final_result_rb = get_result_resume(df_edin_ro,['Roberta_05k','Roberta_1k','Roberta_5k','Roberta_10k','Roberta_25k', 'Roberta_50k','Roberta_250k','Roberta_500k','Roberta_1500k','Roberta_6600k'])
        final_result_bt = get_result_resume(df_edin,['Bertweet_05k','Bertweet_1k','Bertweet_5k','Bertweet_10k','Bertweet_25k', 'Bertweet_50k','Bertweet_250k','Bertweet_500k','Bertweet_1500k','Bertweet_6600k'])
        finals = [final_result_b,final_result_rb,final_result_bt]
        final_result = finals[i]
        sum_win=sum_win+final_result['wins'].values
        sum_rank=sum_rank+final_result['ranksum']
        sum_pos=sum_pos+final_result['position']
        print_dataset = pd.concat([print_dataset, pd.DataFrame(final_result['wins'].map(str)+"/"+final_result['ranksum'].map(str)+"/"+final_result['position'].map(str))],axis=1)

    print_dataset['total'] = pd.DataFrame(sum_win.map(str)+"/"+sum_rank.map(str)+"/"+sum_pos.map(str))
    print_dataset = print_dataset.reset_index() 
    #print_dataset=print_dataset.reindex([10,6,4,2,5,8,9,1,11,12,3,0,7,13])
    #print_dataset['index'] = print_dataset['index'].apply(deParaEmbtName) 
    print_dataset.columns = ['index','RL','SVM','MLP',"RF","Xgb","Total"]

    for ind, row in print_dataset.iterrows():
        print(str(row['index'])+"&"+str(row['RL'])+"&"+str(row['SVM'])+"&"+str(row['MLP'])+"&"+str(row['RF'])+"&"+str(row['Xgb'])+"&"+str(row['Total'])+"\\\\")
        print("\\rule{0pt}{3.8ex}")
# Out:
# Bert_05k&3/127.5/5.5&1/125.5/6.0&1/129.0/7.0&1/153.0/10.0&5/108.0/2.0&11/643.0/30.5\\
# \rule{0pt}{3.8ex}
# Bert_1k&0/134.0/7.0&1/112.0/4.0&1/139.5/8.0&3/114.0/3.5&2/113.5/3.0&7/613.0/25.5\\
# \rule{0pt}{3.8ex}
# Bert_5k&3/115.0/4.0&4/101.0/2.0&3/114.5/5.0&1/120.5/6.0&1/128.0/8.0&12/579.0/25.0\\
# \rule{0pt}{3.8ex}
# Bert_10k&0/143.5/9.0&5/101.5/3.0&1/142.0/10.0&4/119.0/5.0&2/125.5/7.0&12/631.5/34.0\\
# \rule{0pt}{3.8ex}
# Bert_25k&0/136.0/8.0&0/132.5/9.0&0/141.0/9.0&1/134.0/8.0&2/146.0/10.0&3/689.5/44.0\\
# \rule{0pt}{3.8ex}
# Bert_50k&0/146.0/10.0&2/117.0/5.0&2/121.5/6.0&3/113.5/2.0&0/131.5/9.0&7/629.5/32.0\\
# \rule{0pt}{3.8ex}
# Bert_250k&0/127.5/5.5&3/88.0/1.0&3/101.5/1.0&2/73.5/1.0&2/97.5/1.0&10/488.0/9.5\\
# \rule{0pt}{3.8ex}
# Bert_500k&1/110.5/3.0&2/132.0/8.0&2/108.0/4.0&1/114.0/3.5&2/119.5/5.0&8/584.0/23.5\\
# \rule{0pt}{3.8ex}
# Bert_1500k&4/96.0/2.0&2/129.5/7.0&3/107.0/3.0&1/131.5/7.0&1/122.0/6.0&11/586.0/25.0\\
# \rule{0pt}{3.8ex}
# ...

# %%
indexes_=[['Bert_05k','Bert_1k','Bert_5k','Bert_10k','Bert_25k', 'Bert_50k','Bert_250k','Bert_500k','Bert_1500k','Bert_6600k'],
         ['Roberta_05k','Roberta_1k','Roberta_5k','Roberta_10k','Roberta_25k', 'Roberta_50k','Roberta_250k','Roberta_500k','Roberta_1500k','Roberta_6600k'],
         ['Bertweet_05k','Bertweet_1k','Bertweet_5k','Bertweet_10k','Bertweet_25k', 'Bertweet_50k','Bertweet_250k','Bertweet_500k','Bertweet_1500k','Bertweet_6600k']]

         
finals = [final_result_b,final_result_rb,final_result_bt]
for i in range(3):
    indexes = indexes_[i]
    count_model=0
    print_dataset=pd.DataFrame()
    sum_win=pd.Series(0,index=indexes)
    sum_rank=pd.Series(0,index=indexes)
    sum_pos=pd.Series(0,index=indexes)
    for clasf in ['Reg_Logistica_f1_macro','SVM_f1_macro','MLPClassifier_f1_macro',
                  'Random_Forest_f1_macro','XGboost_f1_macro']:
        df_edin_ber,df_edin_ro,df_edin = mont_dataset(clasf)
        final_result_b = get_result_resume(df_edin_ber,['Bert_05k','Bert_1k','Bert_5k','Bert_10k','Bert_25k', 'Bert_50k','Bert_250k','Bert_500k','Bert_1500k','Bert_6600k'])
        final_result_rb = get_result_resume(df_edin_ro,['Roberta_05k','Roberta_1k','Roberta_5k','Roberta_10k','Roberta_25k', 'Roberta_50k','Roberta_250k','Roberta_500k','Roberta_1500k','Roberta_6600k'])
        final_result_bt = get_result_resume(df_edin,['Bertweet_05k','Bertweet_1k','Bertweet_5k','Bertweet_10k','Bertweet_25k', 'Bertweet_50k','Bertweet_250k','Bertweet_500k','Bertweet_1500k','Bertweet_6600k'])
        finals = [final_result_b,final_result_rb,final_result_bt]
        final_result = finals[i]
        sum_win=sum_win+final_result['wins'].values
        sum_rank=sum_rank+final_result['ranksum']
        sum_pos=sum_pos+final_result['position']
        print_dataset = pd.concat([print_dataset, pd.DataFrame(final_result['wins'].map(str)+"/"+final_result['ranksum'].map(str)+"/"+final_result['position'].map(str))],axis=1)

    print_dataset['total'] = pd.DataFrame(sum_win.map(str)+"/"+sum_rank.map(str)+"/"+sum_pos.map(str))
    print_dataset = print_dataset.reset_index() 
    #print_dataset=print_dataset.reindex([10,6,4,2,5,8,9,1,11,12,3,0,7,13])
    #print_dataset['index'] = print_dataset['index'].apply(deParaEmbtName) 
    print_dataset.columns = ['index','RL','SVM','MLP',"RF","Xgb","Total"]

    for ind, row in print_dataset.iterrows():
        print(str(row['index'])+"&"+str(row['RL'])+"&"+str(row['SVM'])+"&"+str(row['MLP'])+"&"+str(row['RF'])+"&"+str(row['Xgb'])+"&"+str(row['Total'])+"\\\\")
        print("\\rule{0pt}{3.8ex}")
# Out:
# Bert_05k&3/128.0/6.0&1/127.0/6.0&1/132.0/7.0&0/155.0/10.0&3/105.5/2.0&8/647.5/31.0\\
# \rule{0pt}{3.8ex}
# Bert_1k&1/140.5/8.0&1/113.0/4.0&1/141.0/9.0&3/113.5/3.0&3/112.0/3.0&9/620.0/27.0\\
# \rule{0pt}{3.8ex}
# Bert_5k&2/120.0/4.0&4/99.5/2.0&3/115.5/5.0&1/118.5/5.0&1/129.5/8.0&11/583.0/24.0\\
# \rule{0pt}{3.8ex}
# Bert_10k&0/144.5/9.0&5/104.5/3.0&1/146.5/10.0&1/124.5/6.0&1/126.0/6.0&8/646.0/34.0\\
# \rule{0pt}{3.8ex}
# Bert_25k&0/140.0/7.0&0/131.0/8.0&0/139.0/8.0&1/136.5/8.0&2/146.5/10.0&3/693.0/41.0\\
# \rule{0pt}{3.8ex}
# Bert_50k&0/148.5/10.0&2/115.0/5.0&2/119.0/6.0&4/106.0/2.0&1/131.5/9.0&9/620.0/32.0\\
# \rule{0pt}{3.8ex}
# Bert_250k&0/122.0/5.0&4/92.0/1.0&3/96.5/1.0&6/68.0/1.0&3/95.5/1.0&16/474.0/9.0\\
# \rule{0pt}{3.8ex}
# Bert_500k&1/108.0/3.0&2/132.0/9.0&2/113.5/4.0&1/116.0/4.0&2/120.0/5.0&8/589.5/25.0\\
# \rule{0pt}{3.8ex}
# Bert_1500k&4/87.5/2.0&2/129.5/7.0&3/104.0/3.0&1/135.0/7.0&0/128.0/7.0&10/584.0/26.0\\
# \rule{0pt}{3.8ex}
# ...
